# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# # Select Structured Dataset

# %%
df = pd.read_csv('data\\structured_data_car_price_prediction.csv')

df.head()
# Out:
#         City FuelType   BodyType KmsDriven TransmissionType  NumberOwner  \
# 0  Bangalore   Petrol  Hatchback  1,20,000           Manual            3
# 1  Bangalore   Petrol        SUV    32,706           Manual            2
# 2  Bangalore   Petrol  Hatchback    11,949           Manual            1
# 3  Bangalore   Petrol      Sedan    17,794           Manual            1
# 4  Bangalore   Diesel        SUV    60,000           Manual            1
#
#   Manufacturer            CarModel  ModelYear  CentralVariantId  ...  \
# 0       Maruti      Maruti Celerio       2015              3979  ...
# 1         Ford       Ford Ecosport       2018              6087  ...
# 2         Tata          Tata Tiago       2018              2983  ...
# 3      Hyundai       Hyundai Xcent       2014              1867  ...
# 4       Maruti  Maruti SX4 S Cross       2015              4277  ...
#
#   Turning Radius  Front Brake Type Rear Brake Type Top Speed   Acceleration  \
# 0     4.7 metres   Ventilated Disc            Drum  150 Kmph  15.05 Seconds
# 1     5.3 metres   Ventilated Disc            Drum       NaN            NaN
# 2     4.9 meters              Disc            Drum  150 kmph   14.3 Seconds
# 3     4.7 metres             Disc             Drum  172km/hr   14.2 Seconds
# 4     5.2 meters   Ventilated Disc      Solid Disc  190 Kmph     12 Seconds
#
#           Tyre Type No Door Numbers Cargo Volumn  Wheel Size Alloy Wheel Size
# 0  Tubeless, Radial             5.0   235-litres         NaN              NaN
# 1   Tubeless,Radial             4.0   352-litres          16               16
# 2          Tubeless             5.0   242-litres          14               14
# 3   Tubeless,Radial             4.0   407-litres          14               14
# 4   Tubeless,Radial             5.0   353-litres          16               16
#
# [5 rows x 53 columns]

# %%
df.isnull().sum()
# Out:
# City                      0
# FuelType                  0
# BodyType                  4
# KmsDriven                 0
# TransmissionType          0
# NumberOwner               0
# Manufacturer              0
# CarModel                  0
# ModelYear                 0
# CentralVariantId          0
# VariantName               0
# Price                     0
# RegistrationYear          0
# Insurance                 0
# Mileage                 287
# Engine                    4
# Max Power                60
# Torque                   60
# Seats                     6
# Color                     3
# Engine Type             295
# Displacement              4
# Max Torque               60
# No of Cylinder           31
# Values per Cylinder      51
# Value Configuration    2216
# Fuel Suppy System      1727
# BoreX Stroke           5964
# Compression Ratio      6474
# Turbo Charger          1040
# Super Charger          1962
# Length                   79
# Width                    83
# Height                   79
# Wheel Base              163
# Front Tread            3558
# Rear Tread             3570
# Kerb Weight              59
# Gross Weight           4541
# Gear Box                106
# Drive Type             1560
# Seating Capacity          6
# Steering Type           255
# Turning Radius         1600
# Front Brake Type         96
# Rear Brake Type          96
# Top Speed              3762
# Acceleration           3512
# Tyre Type                77
# No Door Numbers          11
# Cargo Volumn           1593
# Wheel Size             2983
# Alloy Wheel Size       2983
# dtype: int64

# %%
df.shape

df['Mileage'].unique()
# Out:
# array(['23.1 kmpl', '17 kmpl', '23.84 kmpl', '19.1 kmpl', '23.65 kmpl',
#        '17.1 kmpl', '20.63 kmpl', '18.15 kmpl', '20.28 kmpl', '21.4 kmpl',
#        '18.9 kmpl', '18.2 kmpl', '15.1 kmpl', nan, '21.27 kmpl',
#        '17.33 kmpl', '17.8 kmpl', '18.48 kmpl', '22.38 kmpl',
#        '16.42 kmpl', '7.81 kmpl', '17.4 kmpl', '20.3 kmpl', '13.45 kmpl',
#        '15 kmpl', '17.11 kmpl', '20.14 kmpl', '20.51 kmpl', '19.34 kmpl',
#        '12.6 kmpl', '15.56 kmpl', '11.5 kmpl', '19.87 kmpl', '18.6 kmpl',
#        '22.54 kmpl', '16.3 kmpl', '18.53 kmpl', '22.05 kmpl',
#        '12.05 kmpl', '16.5 kmpl', '19.7 kmpl', '11.3 kmpl', '14.08 kmpl',
#        '12.07 kmpl', '22 kmpl', '21.5 kmpl', '15.3 kmpl', '26.68 kmpl',
#        '21.14 kmpl', '15.9 kmpl', '19.67 kmpl', '14.6 kmpl', '28.4 kmpl',
#        '21.76 kmpl', '26.21 kmpl', '19 kmpl', '19.98 kmpl', '18.5 kmpl',
#        '20 kmpl', '16.8 kmpl', '17.2 kmpl', '21.13 kmpl', '24 kmpl',
#        '25.32 kmpl', '16.55 kmpl', '19.2 kmpl', '24.04 kmpl',
#        '27.03 kmpl', '16.56 kmpl', '19.4 kmpl', '19.56 kmpl',
#        '20.92 kmpl', '19.03 kmpl', '21.1 kmpl', '18.19 kmpl',
#        '17.41 kmpl', '14.2 kmpl', '19.81 kmpl', '14.8 kmpl', '16 kmpl',
#        '18.4 kmpl', '13.2 kmpl', '14.1 kmpl', '20.36 kmpl', '13.24 kmpl',
#        '14.16 kmpl', '24.39 kmpl', '10.91 kmpl', '18.16 kmpl',
#        '20.89 kmpl', '18.1 kmpl', '16.35 kmpl', '15.97 kmpl',
#        '16.07 kmpl', '16.38 kmpl', '14.24 kmpl', '17.9 kmpl',
#        '19.01 kmpl', '25.2 kmpl', '19.6 kmpl', '18 kmpl', '17.21 kmpl',
#        '11.1 kmpl', '11.4 kmpl', '11.72 kmpl', '13.32 kmpl', '20.37 kmpl',
#        '24.3 kmpl', '18.27 kmpl', '20.45 kmpl', '18.7 kmpl', '22.41 kmpl',
#        '20.77 kmpl', '15.63 kmpl', '20.54 kmpl', '21.19 kmpl',
#        '27.39 kmpl', '17.92 kmpl', '26 kmpl', '10 kmpl', '17.5 kmpl',
#        '11.18 kmpl', '23 kmpl', '17.57 kmpl', '14.21 kmpl', '21.43 kmpl',
#        '20.65 kmpl', '22.9 kmpl', '14.5 kmpl', '12.99 kmpl', '19.12 kmpl',
#        '13.8 kmpl', '13.38 kmpl', '14.7 kmpl', '16.36 kmpl', '18.24 kmpl',
#        '21.56 kmpl', '20.38 kmpl', '23.7 kmpl', '20.08 kmpl', '10.9 kmpl',
#        '21.21 kmpl', '15.43 kmpl', '21.74 kmpl', '23.95 kmpl',
#        '19.27 kmpl', '15.4 kmpl', '22.07 kmpl', '20.85 kmpl',
#        '17.01 kmpl', '14.11 kmpl', '22.56 kmpl', '20.5 kmpl', '20.4 kmpl',
#        '20.73 kmpl', '15.6 kmpl', '14.67 kmpl', '19.3 kmpl', '14.71 kmpl',
#        '17.69 kmpl', '13.6 kmpl', '21.72 kmpl', '12.51 kmpl', '16.2 kmpl',
#        '13 kmpl', '17.74 kmpl', '12.55 kmpl', '12.8 kmpl', '22.35 kmpl',
#        '22.77 kmpl', '25.24 kmpl', '17.7 kmpl', '13.06 kmpl', '12.3 kmpl',
#        '17.14 kmpl', '21.03 kmpl', '21.7 kmpl', '23.2 kmpl', '14.69 kmpl',
#        '22.5 kmpl', '20.52 kmpl', '21.46 kmpl', '22.69 kmpl',
#        '22.32 kmpl', '21.01 kmpl', '24.4 kmpl', '17.42 kmpl',
#        '18.56 kmpl', '15.73 kmpl', '17.68 kmpl', '16.13 kmpl',
#        '13.79 kmpl', '18.25 kmpl', '18.3 kmpl', '15.5 kmpl', '15.17 kmpl',
#        '14.99 kmpl', '11.9 kmpl', '15.29 kmpl', '16.09 kmpl',
#        '16.47 kmpl', '20.09 kmpl', '21.63 kmpl', '15.26 kmpl',
#        '11.57 kmpl', '17.03 kmpl', '20.8 kmpl', '17.19 kmpl', '12 kmpl',
#        '23.9 kmpl', '20.04 kmpl', '110 kmpl', '14.59 kmpl', '14 kmpl',
#        '18.45 kmpl', '16.96 kmpl', '12.65 kmpl', '19.33 kmpl',
#        '19.65 kmpl', '22.15 kmpl', '25 kmpl', '14.82 kmpl', '10.75 kmpl',
#        '21.73 kmpl', '8 kmpl', '16.1 kmpl', '20.68 kmpl', '22.7 kmpl',
#        '11.36 kmpl', '13.4 kmpl', '18.49 kmpl', '14.28 kmpl',
#        '17.88 kmpl', '16.11 kmpl', '20.7 kmpl', '16.82 kmpl', '17.3 kmpl',
#        '20.46 kmpl', '12.35 kmpl', '15.04 kmpl', '18.75 kmpl',
#        '15.2 kmpl', '18.12 kmpl', '18.06 kmpl', '11.7 kmpl', '20.1 kmpl',
#        '22.74 kmpl', '28.09 kmpl', '17.67 kmpl', '20.88 km/kg',
#        '26.11 kmpl', '22.1 kmpl', '13.5 kmpl', '24.52 kmpl', '20.25 kmpl',
#        '13.58 kmpl', '10.54 kmpl', '15.7 kmpl', '19.64 kmpl', '140 kmpl',
#        '13.68 kmpl', '16.24 kmpl', '26.59 kmpl', '13.7 kmpl', '17.6 kmpl',
#        '19.69 kmpl', '15.41 kmpl', '14.9 kmpl', '17.52 kmpl',
#        '17.05 kmpl', '24.7 kmpl', '21.9 kmpl', '25.4 kmpl', '19.47 kmpl',
#        '21.66 kmpl', '25.8 kmpl', '10.5 kmpl', '14.4 kmpl', '9 kmpl',
#        '19.09 kmpl', '23.01 kmpl', '22.25 kmpl', '27.28 kmpl',
#        '21.64 kmpl', '22.61 kmpl', '15.8 kmpl', '18.09 kmpl',
#        '19.28 kmpl', '18.78 kmpl', '11.74 kmpl', '8.9 kmpl', '15.85 kmpl',
#        '18.76 kmpl', '16.95 kmpl', '23.59 kmpl', '14.84 kmpl',
#        '19.5 kmpl', '21 kmpl', '15.96 kmpl', '27.3 kmpl', '18.88 kmpl',
#        '13.93 kmpl', '14.74 kmpl', '16.4 kmpl', '16.28 kmpl',
#        '20.86 kmpl', '18.07 kmpl', '21.79 kmpl', '16.6 kmpl', '13.9 kmpl',
#        '26.1 kmpl', '13.92 kmpl', '18.55 kmpl', '14.02 kmpl',
#        '31.59 km/kg', '19.72 kmpl', '14.57 kmpl', '21.8 kmpl',
#        '19.16 kmpl', '25.17 kmpl', '22.3 kmpl', '24.35 kmpl', '13.1 kmpl',
#        '12.1 kmpl', '25.1 kmpl', '35.6 km/kg', '14.53 kmpl', '11.2 kmpl',
#        '12.2 kmpl', '12.4 kmpl', '26.49 km/kg', '26.49 kmpl', '26.2 kmpl',
#        '25.47 kmpl', '17.09 kmpl', '16.25 kmpl', '21.02 kmpl',
#        '16.02 kmpl', '24.76 kmpl', '19.49 kmpl', '30.48 km/kg',
#        '13.96 kmpl', '11.67 kmpl', '19.17 kmpl', '9.4 kmpl', '7.5 kmpl',
#        '12.18 kmpl', '17.32 kmpl', '13.44 kmpl', '20.34 kmpl',
#        '23.64 kmpl', '17.71 kmpl', '14.3 kmpl', '16.78 kmpl',
#        '22.95 kmpl', '18.69 kmpl', '14.94 kmpl', '16.9 kmpl',
#        '19.89 kmpl', '32.52 kmpl', '14.62 kmpl', '23.03 kmpl',
#        '16.73 kmpl', '25.83 kmpl', '15.64 kmpl', '25.44 kmpl',
#        '15.39 kmpl', '24.97 kmpl', '34.05 kmpl', '23.08 kmpl',
#        '17.85 kmpl', '20.71 kmpl', '19.61 kmpl', '25.01 kmpl',
#        '21.38 kmpl', '24.2 kmpl', '17.29 kmpl', '15.68 kmpl',
#        '27.97 kmpl', '19.68 kmpl', '18.23 kmpl', '27.4 kmpl',
#        '23.56 kmpl', '23.4 kmpl', '19.08 kmpl', '18.97 kmpl',
#        '14.34 kmpl', '20.62 kmpl', '19.71 kmpl', '15.15 kmpl',
#        '15.37 kmpl', '25.5 kmpl', '19.8 kmpl', '12.62 kmpl', '12.9 kmpl',
#        '10.93 kmpl', '14.95 kmpl', '12.81 kmpl', '11.81 kmpl',
#        '25.6 kmpl', '17.43 kmpl', '16.7 kmpl', '12.98 kmpl', '16.65 kmpl',
#        '19.44 kmpl', '19.02 kmpl', '12.34 kmpl', '21.11 kmpl',
#        '14.23 kmpl', '27.62 kmpl', '26.82 kmpl', '11 kmpl', '25.3 kmpl',
#        '19.95 kmpl', '19.83 kmpl', '21.12 kmpl', '11.96 kmpl',
#        '23.8 kmpl', '13.47 kmpl', '31.12 kmpl', '23.22 kmpl',
#        '17.38 kmpl', '17.97 kmpl', '20.58 kmpl', '22.27 kmpl',
#        '16.97 kmpl', '13.33 kmpl', '19.59 kmpl', '18.41 kmpl',
#        '26.5 kmpl', '22.71 kmpl', '12.7 kmpl', '16.14 kmpl', '33.54 kmpl',
#        '19.15 kmpl', '15.81 kmpl', '24.1 kmpl', '30.47 km/kg',
#        '21.49 kmpl', '17.99 kmpl', '14.47 kmpl', '21.1 km/kg',
#        '18.43 kmpl', '12.12 kmpl', '26.8 kmpl', '9.74 kmpl', '18.8 kmpl',
#        '12.74 kmpl', '28 km/kg', '12.5 kmpl', '15.34 kmpl', '14.025 kmpl',
#        '26.08 km/kg', '9.2 kmpl', '16.34 kmpl', '30.46 kmpl',
#        '11.21 kmpl', '13.22 kmpl', '16.39 kmpl', '12.04 kmpl',
#        '14.75 kmpl', '16.12 kmpl', '26.55 kmpl', '7.08 kmpl', '31.2 kmpl',
#        '12.33 kmpl', '31.79 kmpl', '8.13 kmpl', '16.72 kmpl',
#        '19.23 kmpl', '22.48 kmpl', '20.6 kmpl', '14.01 kmpl', '10.8 kmpl',
#        '9.26 kmpl', '12.95 kmpl', '10.4 kmpl', '20.15 kmpl',
#        '31.12 km/kg', '11.88 kmpl', '18.9 km/kg', '18.05 kmpl',
#        '15.01 kmpl', '10.26 kmpl', '19.39 kmpl', '8.45 kmpl',
#        '26.11 km/kg', '12.63 kmpl', '26.6 kmpl', '10.13 kmpl',
#        '20.27 kmpl', '14.09 kmpl', '20.01 kmpl', '26.6 km/kg',
#        '26.83 kmpl', '16.77 kmpl', '23.57 kmpl', '12.83 kmpl',
#        '16.98 kmpl', '24.8 kmpl', '13.01 kmpl', '7.94 kmpl', '18.33 kmpl',
#        '13.53 kmpl', '16.46 kmpl', '18.86 kmpl', '12.08 kmpl', '8.5 kmpl',
#        '18.72 kmpl', '13.17 kmpl', '19.62 kmpl', '9.8 kmpl', '13.14 kmpl',
#        '11.33 kmpl', '25.19 kmpl', '24.29 kmpl', '12.78 kmpl',
#        '14.49 kmpl', '14.19 kmpl', '19.19 kmpl', '11.24 kmpl',
#        '22.37 kmpl', '14.85 kmpl'], dtype=object)

# %% [markdown]
# # Selecting dependent variables

# %% [markdown]
# Removing unwanted columns and only selecting dependent variables

# %%
required_columns = ['City','FuelType', 'BodyType', 'KmsDriven', 'TransmissionType', 'NumberOwner', 'Insurance', 'Manufacturer',
    'CarModel', 'ModelYear', 'VariantName', 'Mileage', 'Engine', 'Price', 'No of Cylinder', 'Seats'
] 

# Check which of these columns exist in the DataFrame
available_columns = [col for col in required_columns if col in df.columns]

# If some columns are missing, print them out (optional)
missing_columns = set(required_columns) - set(available_columns)
if missing_columns:
    print(f"The following columns are missing from the DataFrame: {missing_columns}")

# Extract the available columns from the DataFrame
df_filtered = df[available_columns]

# Show the filtered DataFrame
df_filtered.head()
# Out:
#         City FuelType   BodyType KmsDriven TransmissionType  NumberOwner  \
# 0  Bangalore   Petrol  Hatchback  1,20,000           Manual            3
# 1  Bangalore   Petrol        SUV    32,706           Manual            2
# 2  Bangalore   Petrol  Hatchback    11,949           Manual            1
# 3  Bangalore   Petrol      Sedan    17,794           Manual            1
# 4  Bangalore   Diesel        SUV    60,000           Manual            1
#
#                Insurance Manufacturer            CarModel  ModelYear  \
# 0  Third Party insurance       Maruti      Maruti Celerio       2015
# 1          Comprehensive         Ford       Ford Ecosport       2018
# 2          Comprehensive         Tata          Tata Tiago       2018
# 3          Comprehensive      Hyundai       Hyundai Xcent       2014
# 4  Third Party insurance       Maruti  Maruti SX4 S Cross       2015
#
#                 VariantName     Mileage   Engine     Price  No of Cylinder  \
# 0                       VXI   23.1 kmpl   998 CC  400000.0             3.0
# 1  1.5 Petrol Titanium BSIV     17 kmpl  1497 CC  811000.0             3.0
# 2           1.2 Revotron XZ  23.84 kmpl  1199 CC  585000.0             3.0
# 3        1.2 Kappa S Option   19.1 kmpl  1197 CC  462000.0             4.0
# 4             DDiS 200 Zeta  23.65 kmpl  1248 CC  790000.0             4.0
#
#    Seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
print(df_filtered.isnull().sum())
# Out:
# City                  0
# FuelType              0
# BodyType              4
# KmsDriven             0
# TransmissionType      0
# NumberOwner           0
# Insurance             0
# Manufacturer          0
# CarModel              0
# ModelYear             0
# VariantName           0
# Mileage             287
# Engine                4
# Price                 0
# No of Cylinder       31
# Seats                 6
# dtype: int64

# %%
print(df_filtered.dtypes)
# Out:
# City                 object
# FuelType             object
# BodyType             object
# KmsDriven            object
# TransmissionType     object
# NumberOwner           int64
# Insurance            object
# Manufacturer         object
# CarModel             object
# ModelYear             int64
# VariantName          object
# Mileage              object
# Engine               object
# Price               float64
# No of Cylinder      float64
# Seats               float64
# dtype: object

# %% [markdown]
# # Age of Car

# %% [markdown]
# New Column age of car added

# %%
def create_current_year(row):
    current_year = pd.Timestamp.now().year
    return current_year - row['ModelYear']

# Apply the function to create a new feature 'current_year'
df_filtered['AgeOfCar'] = df_filtered.apply(create_current_year, axis=1)

df_filtered
# Out:
#            City FuelType   BodyType KmsDriven TransmissionType  NumberOwner  \
# 0     Bangalore   Petrol  Hatchback  1,20,000           Manual            3
# 1     Bangalore   Petrol        SUV    32,706           Manual            2
# 2     Bangalore   Petrol  Hatchback    11,949           Manual            1
# 3     Bangalore   Petrol      Sedan    17,794           Manual            1
# 4     Bangalore   Diesel        SUV    60,000           Manual            1
# ...         ...      ...        ...       ...              ...          ...
# 8364    Chennai   Petrol  Hatchback    42,891        Automatic            1
# 8365    Chennai   Diesel        SUV    59,100           Manual            1
# 8366    Chennai   Petrol        SUV    55,913        Automatic            1
# 8367    Chennai   Diesel        SUV    65,000        Automatic            1
# 8368    Chennai   Diesel      Sedan    60,000        Automatic            1
#
#                   Insurance Manufacturer            CarModel  ModelYear  \
# 0     Third Party insurance       Maruti      Maruti Celerio       2015
# 1             Comprehensive         Ford       Ford Ecosport       2018
# 2             Comprehensive         Tata          Tata Tiago       2018
# 3             Comprehensive      Hyundai       Hyundai Xcent       2014
# 4     Third Party insurance       Maruti  Maruti SX4 S Cross       2015
# ...                     ...          ...                 ...        ...
# 8364  Third Party insurance       Maruti        Maruti Swift       2018
# 8365  Third Party insurance      Renault      Renault Duster       2018
# 8366          Not Available         Tata          Tata Nexon       2018
# 8367          Comprehensive   Volkswagen   Volkswagen Tiguan       2017
# 8368          Comprehensive          BMW     BMW 3 Series GT       2019
#
#                    VariantName     Mileage   Engine      Price  \
# 0                          VXI   23.1 kmpl   998 CC   400000.0
# 1     1.5 Petrol Titanium BSIV     17 kmpl  1497 CC   811000.0
# 2              1.2 Revotron XZ  23.84 kmpl  1199 CC   585000.0
# 3           1.2 Kappa S Option   19.1 kmpl  1197 CC   462000.0
# 4                DDiS 200 Zeta  23.65 kmpl  1248 CC   790000.0
# ...                        ...         ...      ...        ...
# 8364                   AMT VXI     22 kmpl  1197 CC   620000.0
# 8365           85PS Diesel RxZ  19.87 kmpl  1461 CC   890000.0
# 8366     1.2 Revotron XZA Plus     17 kmpl  1198 CC   801000.0
# 8367          2.0 TDI Highline  16.65 kmpl  1968 CC  2050000.0
# 8368                     Sport  21.76 kmpl  1995 CC  3575000.0
#
#       No of Cylinder  Seats  AgeOfCar
# 0                3.0    5.0         9
# 1                3.0    5.0         6
# 2                3.0    5.0         6
# 3                4.0    5.0        10
# 4                4.0    5.0         9
# ...              ...    ...       ...
# 8364             4.0    5.0         6
# 8365             4.0    5.0         6
# 8366             3.0    5.0         6
# 8367             4.0    5.0         7
# 8368             4.0    5.0         5
#
# [8369 rows x 17 columns]

# %% [markdown]
# # Removing null values

# %%
df_filtered.drop_duplicates(inplace=True)

# %%
# Drop columns with more than 50% missing values
df_filtered = df_filtered.dropna(thresh=len(df_filtered)*0.5, axis=1)

# Drop rows with any missing values
df_filtered = df_filtered.dropna()

print(df_filtered.isnull().sum())
# Out:
# City                0
# FuelType            0
# BodyType            0
# KmsDriven           0
# TransmissionType    0
# NumberOwner         0
# Insurance           0
# Manufacturer        0
# CarModel            0
# ModelYear           0
# VariantName         0
# Mileage             0
# Engine              0
# Price               0
# No of Cylinder      0
# Seats               0
# AgeOfCar            0
# dtype: int64

# %%
df_filtered.shape
# Out:
# (7966, 17)

# %% [markdown]
# # Cleaning Mileage Column

# %%
df_filtered['Mileage'].value_counts()
# Out:
# 18.9 kmpl     306
# 18.6 kmpl     224
# 21.4 kmpl     196
# 17 kmpl       189
# 18 kmpl       144
#              ...
# 16.97 kmpl      1
# 17.97 kmpl      1
# 11.96 kmpl      1
# 10.75 kmpl      1
# 14.85 kmpl      1
# Name: Mileage, Length: 521, dtype: int64

# %%
df_filtered['Mileage'] = df_filtered['Mileage'].astype(str)

# Remove the 'kmpl' suffix and convert to numeric
df_filtered['Mileage'] = df_filtered['Mileage'].str.replace(' kmpl', '', regex=False)
df_filtered['Mileage'] = df_filtered['Mileage'].str.replace(' km/kg', '', regex=False)
df_filtered['Mileage'] = pd.to_numeric(df_filtered['Mileage'], errors='coerce')


df_filtered.isnull().sum()
# Out:
# City                0
# FuelType            0
# BodyType            0
# KmsDriven           0
# TransmissionType    0
# NumberOwner         0
# Insurance           0
# Manufacturer        0
# CarModel            0
# ModelYear           0
# VariantName         0
# Mileage             0
# Engine              0
# Price               0
# No of Cylinder      0
# Seats               0
# AgeOfCar            0
# dtype: int64

# %% [markdown]
# # Cleanig KmsDriven Column

# %%
df_filtered['KmsDriven'] = df_filtered['KmsDriven'].astype(str)
# Step 1: Remove commas
df_filtered['KmsDriven'] = df_filtered['KmsDriven'].str.replace(',', '')

# Step 2: Convert to integer
df_filtered['KmsDriven'] = df_filtered['KmsDriven'].astype(float)

# Display the DataFrame
df_filtered
# Out:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 0     Bangalore   Petrol  Hatchback   120000.0           Manual            3
# 1     Bangalore   Petrol        SUV    32706.0           Manual            2
# 2     Bangalore   Petrol  Hatchback    11949.0           Manual            1
# 3     Bangalore   Petrol      Sedan    17794.0           Manual            1
# 4     Bangalore   Diesel        SUV    60000.0           Manual            1
# ...         ...      ...        ...        ...              ...          ...
# 8364    Chennai   Petrol  Hatchback    42891.0        Automatic            1
# 8365    Chennai   Diesel        SUV    59100.0           Manual            1
# 8366    Chennai   Petrol        SUV    55913.0        Automatic            1
# 8367    Chennai   Diesel        SUV    65000.0        Automatic            1
# 8368    Chennai   Diesel      Sedan    60000.0        Automatic            1
#
#                   Insurance Manufacturer            CarModel  ModelYear  \
# 0     Third Party insurance       Maruti      Maruti Celerio       2015
# 1             Comprehensive         Ford       Ford Ecosport       2018
# 2             Comprehensive         Tata          Tata Tiago       2018
# 3             Comprehensive      Hyundai       Hyundai Xcent       2014
# 4     Third Party insurance       Maruti  Maruti SX4 S Cross       2015
# ...                     ...          ...                 ...        ...
# 8364  Third Party insurance       Maruti        Maruti Swift       2018
# 8365  Third Party insurance      Renault      Renault Duster       2018
# 8366          Not Available         Tata          Tata Nexon       2018
# 8367          Comprehensive   Volkswagen   Volkswagen Tiguan       2017
# 8368          Comprehensive          BMW     BMW 3 Series GT       2019
#
#                    VariantName  Mileage   Engine      Price  No of Cylinder  \
# 0                          VXI    23.10   998 CC   400000.0             3.0
# 1     1.5 Petrol Titanium BSIV    17.00  1497 CC   811000.0             3.0
# 2              1.2 Revotron XZ    23.84  1199 CC   585000.0             3.0
# 3           1.2 Kappa S Option    19.10  1197 CC   462000.0             4.0
# 4                DDiS 200 Zeta    23.65  1248 CC   790000.0             4.0
# ...                        ...      ...      ...        ...             ...
# 8364                   AMT VXI    22.00  1197 CC   620000.0             4.0
# 8365           85PS Diesel RxZ    19.87  1461 CC   890000.0             4.0
# 8366     1.2 Revotron XZA Plus    17.00  1198 CC   801000.0             3.0
# 8367          2.0 TDI Highline    16.65  1968 CC  2050000.0             4.0
# 8368                     Sport    21.76  1995 CC  3575000.0             4.0
#
#       Seats  AgeOfCar
# 0       5.0         9
# 1       5.0         6
# 2       5.0         6
# 3       5.0        10
# 4       5.0         9
# ...     ...       ...
# 8364    5.0         6
# 8365    5.0         6
# 8366    5.0         6
# 8367    5.0         7
# 8368    5.0         5
#
# [7966 rows x 17 columns]

# %% [markdown]
# # Cleaning Engine Column

# %%
df_filtered['Engine'] = df_filtered['Engine'].astype(str)

# Remove the 'CC' suffix and convert to numeric
df_filtered['Engine'] = df_filtered['Engine'].str.replace(' CC', '', regex=False)
df_filtered['Engine'] = df_filtered['Engine'].astype(float)

df_filtered
# Out:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 0     Bangalore   Petrol  Hatchback   120000.0           Manual            3
# 1     Bangalore   Petrol        SUV    32706.0           Manual            2
# 2     Bangalore   Petrol  Hatchback    11949.0           Manual            1
# 3     Bangalore   Petrol      Sedan    17794.0           Manual            1
# 4     Bangalore   Diesel        SUV    60000.0           Manual            1
# ...         ...      ...        ...        ...              ...          ...
# 8364    Chennai   Petrol  Hatchback    42891.0        Automatic            1
# 8365    Chennai   Diesel        SUV    59100.0           Manual            1
# 8366    Chennai   Petrol        SUV    55913.0        Automatic            1
# 8367    Chennai   Diesel        SUV    65000.0        Automatic            1
# 8368    Chennai   Diesel      Sedan    60000.0        Automatic            1
#
#                   Insurance Manufacturer            CarModel  ModelYear  \
# 0     Third Party insurance       Maruti      Maruti Celerio       2015
# 1             Comprehensive         Ford       Ford Ecosport       2018
# 2             Comprehensive         Tata          Tata Tiago       2018
# 3             Comprehensive      Hyundai       Hyundai Xcent       2014
# 4     Third Party insurance       Maruti  Maruti SX4 S Cross       2015
# ...                     ...          ...                 ...        ...
# 8364  Third Party insurance       Maruti        Maruti Swift       2018
# 8365  Third Party insurance      Renault      Renault Duster       2018
# 8366          Not Available         Tata          Tata Nexon       2018
# 8367          Comprehensive   Volkswagen   Volkswagen Tiguan       2017
# 8368          Comprehensive          BMW     BMW 3 Series GT       2019
#
#                    VariantName  Mileage  Engine      Price  No of Cylinder  \
# 0                          VXI    23.10   998.0   400000.0             3.0
# 1     1.5 Petrol Titanium BSIV    17.00  1497.0   811000.0             3.0
# 2              1.2 Revotron XZ    23.84  1199.0   585000.0             3.0
# 3           1.2 Kappa S Option    19.10  1197.0   462000.0             4.0
# 4                DDiS 200 Zeta    23.65  1248.0   790000.0             4.0
# ...                        ...      ...     ...        ...             ...
# 8364                   AMT VXI    22.00  1197.0   620000.0             4.0
# 8365           85PS Diesel RxZ    19.87  1461.0   890000.0             4.0
# 8366     1.2 Revotron XZA Plus    17.00  1198.0   801000.0             3.0
# 8367          2.0 TDI Highline    16.65  1968.0  2050000.0             4.0
# 8368                     Sport    21.76  1995.0  3575000.0             4.0
#
#       Seats  AgeOfCar
# 0       5.0         9
# 1       5.0         6
# 2       5.0         6
# 3       5.0        10
# 4       5.0         9
# ...     ...       ...
# 8364    5.0         6
# 8365    5.0         6
# 8366    5.0         6
# 8367    5.0         7
# 8368    5.0         5
#
# [7966 rows x 17 columns]

# %%
print(df_filtered.dtypes)
# Out:
# City                 object
# FuelType             object
# BodyType             object
# KmsDriven           float64
# TransmissionType     object
# NumberOwner           int64
# Insurance            object
# Manufacturer         object
# CarModel             object
# ModelYear             int64
# VariantName          object
# Mileage             float64
# Engine              float64
# Price               float64
# No of Cylinder      float64
# Seats               float64
# AgeOfCar              int64
# dtype: object

# %%
df_filtered['KmsDriven'] = df_filtered['KmsDriven'].astype('int64')
df_filtered['Mileage'] = df_filtered['Mileage'].astype('int64')
df_filtered['Engine'] = df_filtered['Engine'].astype('int64')
df_filtered['No of Cylinder'] = df_filtered['No of Cylinder'].astype('int64')
df_filtered['Seats'] = df_filtered['Seats'].astype('int64')
df_filtered['AgeOfCar'] = df_filtered['AgeOfCar'].astype('int64')

print(df_filtered.dtypes)

df_filtered
# Out:
# City                 object
# FuelType             object
# BodyType             object
# KmsDriven             int64
# TransmissionType     object
# NumberOwner           int64
# Insurance            object
# Manufacturer         object
# CarModel             object
# ModelYear             int64
# VariantName          object
# Mileage               int64
# Engine                int64
# Price               float64
# No of Cylinder        int64
# Seats                 int64
# AgeOfCar              int64
# dtype: object
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 0     Bangalore   Petrol  Hatchback     120000           Manual            3
# 1     Bangalore   Petrol        SUV      32706           Manual            2
# 2     Bangalore   Petrol  Hatchback      11949           Manual            1
# 3     Bangalore   Petrol      Sedan      17794           Manual            1
# 4     Bangalore   Diesel        SUV      60000           Manual            1
# ...         ...      ...        ...        ...              ...          ...
# 8364    Chennai   Petrol  Hatchback      42891        Automatic            1
# 8365    Chennai   Diesel        SUV      59100           Manual            1
# 8366    Chennai   Petrol        SUV      55913        Automatic            1
# 8367    Chennai   Diesel        SUV      65000        Automatic            1
# 8368    Chennai   Diesel      Sedan      60000        Automatic            1
#
#                   Insurance Manufacturer            CarModel  ModelYear  \
# 0     Third Party insurance       Maruti      Maruti Celerio       2015
# 1             Comprehensive         Ford       Ford Ecosport       2018
# 2             Comprehensive         Tata          Tata Tiago       2018
# 3             Comprehensive      Hyundai       Hyundai Xcent       2014
# 4     Third Party insurance       Maruti  Maruti SX4 S Cross       2015
# ...                     ...          ...                 ...        ...
# 8364  Third Party insurance       Maruti        Maruti Swift       2018
# 8365  Third Party insurance      Renault      Renault Duster       2018
# 8366          Not Available         Tata          Tata Nexon       2018
# 8367          Comprehensive   Volkswagen   Volkswagen Tiguan       2017
# 8368          Comprehensive          BMW     BMW 3 Series GT       2019
#
#                    VariantName  Mileage  Engine      Price  No of Cylinder  \
# 0                          VXI       23     998   400000.0               3
# 1     1.5 Petrol Titanium BSIV       17    1497   811000.0               3
# 2              1.2 Revotron XZ       23    1199   585000.0               3
# 3           1.2 Kappa S Option       19    1197   462000.0               4
# 4                DDiS 200 Zeta       23    1248   790000.0               4
# ...                        ...      ...     ...        ...             ...
# 8364                   AMT VXI       22    1197   620000.0               4
# 8365           85PS Diesel RxZ       19    1461   890000.0               4
# 8366     1.2 Revotron XZA Plus       17    1198   801000.0               3
# 8367          2.0 TDI Highline       16    1968  2050000.0               4
# 8368                     Sport       21    1995  3575000.0               4
#
#       Seats  AgeOfCar
# 0         5         9
# 1         5         6
# 2         5         6
# 3         5        10
# 4         5         9
# ...     ...       ...
# 8364      5         6
# 8365      5         6
# 8366      5         6
# 8367      5         7
# 8368      5         5
#
# [7966 rows x 17 columns]

# %% [markdown]
# # Spliting Categorical and Numerical Featues

# %%
print('Missing Value Presence in different columns of DataFrame are as follows : ')
print('-'*100)
total = df_filtered.isnull().sum().sort_values(ascending=False)
percent=(df_filtered.isnull().sum()/df_filtered.isnull().count()*100).sort_values(ascending=False)
pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

numeric_features = [feature for feature in df_filtered.columns if df_filtered[feature].dtype != 'O']
categorical_features = [feature for feature in df_filtered.columns if df_filtered[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# Missing Value Presence in different columns of DataFrame are as follows :
# ----------------------------------------------------------------------------------------------------
# We have 9 numerical features : ['KmsDriven', 'NumberOwner', 'ModelYear', 'Mileage', 'Engine', 'Price', 'No of Cylinder', 'Seats', 'AgeOfCar']
#
# We have 8 categorical features : ['City', 'FuelType', 'BodyType', 'TransmissionType', 'Insurance', 'Manufacturer', 'CarModel', 'VariantName']

# %%
print('Summary Statistics of numerical features for DataFrame are as follows:')
print('-'*100)
df_filtered.describe()
# Out:
# Summary Statistics of numerical features for DataFrame are as follows:
# ----------------------------------------------------------------------------------------------------
#           KmsDriven  NumberOwner    ModelYear      Mileage       Engine  \
# count  7.966000e+03  7966.000000  7966.000000  7966.000000  7966.000000
# mean   5.975941e+04     1.362917  2016.414261    18.838940  1417.560633
# std    7.429062e+04     0.640916     3.799510     3.918734   463.656029
# min    0.000000e+00     0.000000  1985.000000     7.000000    72.000000
# 25%    3.200000e+04     1.000000  2014.000000    17.000000  1197.000000
# 50%    5.500000e+04     1.000000  2017.000000    18.000000  1199.000000
# 75%    8.000000e+04     2.000000  2019.000000    21.000000  1498.000000
# max    5.500000e+06     5.000000  2023.000000   140.000000  5000.000000
#
#               Price  No of Cylinder       Seats     AgeOfCar
# count  7.966000e+03     7966.000000  7966.00000  7966.000000
# mean   8.959430e+05        3.792493     5.19872     7.585739
# std    1.161776e+06        0.592694     0.65166     3.799510
# min    2.016100e+04        2.000000     2.00000     1.000000
# 25%    3.950000e+05        4.000000     5.00000     5.000000
# 50%    5.990000e+05        4.000000     5.00000     7.000000
# 75%    9.000000e+05        4.000000     5.00000    10.000000
# max    2.600000e+07       23.000000    10.00000    39.000000

# %%
print('-'*100)
print('The percentage of each category in categorical column are as follow : ')
print('-'*100 +'\n')
for col in categorical_features:
    print(df_filtered[col].value_counts(normalize=True) * 100)
    print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# The percentage of each category in categorical column are as follow :
# ----------------------------------------------------------------------------------------------------
#
# Hyderabad    17.813206
# Bangalore    17.788099
# Delhi        17.411499
# Chennai      17.160432
# Kolkata      16.482551
# Jaipur       13.344213
# Name: City, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Petrol      67.009792
# Diesel      31.697213
# Cng          1.092142
# Lpg          0.188300
# Electric     0.012553
# Name: FuelType, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Hatchback        43.786091
# Sedan            26.587999
# SUV              24.968617
# MUV               4.155159
# Minivans          0.263620
# Coupe             0.112980
# Convertibles      0.075320
# Pickup Trucks     0.025107
# Wagon             0.012553
# Hybrids           0.012553
# Name: BodyType, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Manual       73.361788
# Automatic    26.638212
# Name: TransmissionType, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Third Party insurance    47.665077
# Comprehensive            37.660055
# Third Party               7.607331
# Zero Dep                  3.740899
# Not Available             2.686417
# Petrol                    0.451921
# Diesel                    0.138087
# 1                         0.037660
# 2                         0.012553
# Name: Insurance, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Maruti                27.692694
# Hyundai               19.445142
# Honda                 10.733116
# Tata                   5.159428
# Mahindra               4.017073
# Toyota                 3.904092
# Renault                3.878986
# Ford                   3.828772
# Volkswagen             3.552599
# Mercedes-Benz          2.598544
# BMW                    2.272157
# Skoda                  1.983430
# Audi                   1.845343
# Kia                    1.619382
# Jeep                   1.355762
# Nissan                 0.966608
# Chevrolet              0.954055
# Datsun                 0.928948
# MG                     0.841075
# Volvo                  0.464474
# Land Rover             0.439367
# Jaguar                 0.414261
# Fiat                   0.376601
# Mitsubishi             0.163194
# Mini                   0.138087
# Citroen                0.100427
# Porsche                0.062767
# Isuzu                  0.062767
# Mahindra Ssangyong     0.050213
# Mahindra Renault       0.050213
# Opel                   0.037660
# Lexus                  0.037660
# Hindustan Motors       0.025107
# Name: Manufacturer, dtype: float64
# ----------------------------------------------------------------------------------------------------
# Honda City               4.594527
# Maruti Swift             4.356013
# Hyundai i20              4.117499
# Maruti Baleno            3.653025
# Hyundai Grand i10        3.251318
#                            ...
# Fiat Abarth Avventura    0.012553
# Tata Indigo Marina       0.012553
# Chevrolet Captiva        0.012553
# Toyota Qualis            0.012553
# Mahindra TUV 300 Plus    0.012553
# Name: CarModel, Length: 281, dtype: float64
# ----------------------------------------------------------------------------------------------------
# VXI                 4.180266
# LXI                 1.770023
# Sportz              1.205122
# VDI                 0.979161
# Magna               0.966608
#                       ...
# Technology BSVI     0.012553
# ZXI 2018            0.012553
# XM Diesel           0.012553
# XL D Option         0.012553
# 2.0 TDI Highline    0.012553
# Name: VariantName, Length: 2022, dtype: float64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
# Ensure all numeric columns are actually numeric
numeric_features = df_filtered.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Plot
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.0)

# Iterate through numeric features for plotting
for i in range(len(numeric_features)):
    plt.subplot(3, 3, i+1)
    sns.kdeplot(x=df_filtered[numeric_features[i]], shade=True, color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

plt.show()

# %% [markdown]
# ### Box Plot of Numerical Features

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Box Plot of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.0)

for i in range(0, len(numeric_features)):
    plt.subplot(3, 3, i+1)
    sns.boxplot(x=df_filtered[numeric_features[i]])
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
car_corr = df_filtered[numeric_features].corr()
car_corr

plt.figure(figsize=(15,10))
sns.heatmap(car_corr, annot= True, cmap= 'plasma', vmin= -1 , vmax= 1, linecolor='white', linewidths=2)
plt.show()

# %% [markdown]
# # Cleaning Outliers Column in Dataset

# %% [markdown]
# We can use the Interquartile Range (IQR) method to detect and visualize outliers.

# %%
def detect_outliers_iqr(df_d, column):
    """
    Detects outliers in the given column of the dataframe using the IQR method.
    """
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df_d[column].quantile(0.25)
    Q3 = df_d[column].quantile(0.75)

    # IQR is the difference between Q3 and Q1
    IQR = Q3 - Q1

    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df_d[(df_d[column] < lower_bound) | (df_d[column] > upper_bound)]
    
    print(f"Number of outliers in {column}: {len(outliers)}")
    
    return outliers


# Apply the function to KmsDriven, Price, and AgeOfCar
outliers_kms_driven = detect_outliers_iqr(df_filtered, 'KmsDriven')
outliers_price = detect_outliers_iqr(df_filtered, 'Price')
outliers_mileage_car = detect_outliers_iqr(df_filtered, 'Mileage')
outliers_age_of_car = detect_outliers_iqr(df_filtered, 'AgeOfCar')

# Display the outliers
print("Outliers in KmsDriven:")
print(outliers_kms_driven)

print("\nOutliers in Price:")
print(outliers_price)

print("\nOutliers in AgeOfCar:")
print(outliers_age_of_car)

print("\nOutliers in Mileage:")
print(outliers_mileage_car)
# Out:
# Number of outliers in KmsDriven: 52
# Number of outliers in Price: 839
# Number of outliers in Mileage: 183
# Number of outliers in AgeOfCar: 112
# Outliers in KmsDriven:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 304   Bangalore   Diesel        SUV     164000           Manual            2
# 333   Bangalore   Diesel        SUV     174000        Automatic            3
# 336   Bangalore   Diesel        MUV     199000           Manual            2
# 1230  Bangalore   Diesel        MUV     162000           Manual            1
# 1234  Bangalore   Diesel        SUV     180000           Manual            2
# 1282  Bangalore   Diesel        SUV     174000           Manual            1
# 1285  Bangalore   Diesel        SUV     170402        Automatic            2
# 1301  Bangalore   Diesel        MUV     157000           Manual            2
# 1403  Bangalore   Diesel        MUV     169219           Manual            2
# 1476  Bangalore   Diesel        SUV     156039           Manual            2
# 1600    Kolkata   Diesel        MUV     260000           Manual            1
# 1693    Kolkata   Diesel        MUV     177000           Manual            1
# 2103    Kolkata   Petrol        SUV     975000           Manual            1
# 3006  Hyderabad   Diesel        SUV     158000        Automatic            2
# 3020  Hyderabad   Diesel  Hatchback     188058           Manual            1
# 3476  Hyderabad   Diesel      Sedan     171000           Manual            3
# 3597  Hyderabad   Diesel      Sedan     156126           Manual            1
# 3636  Hyderabad   Diesel        MUV     236000           Manual            1
# 4888      Delhi   Diesel        SUV     230000           Manual            1
# 5892     Jaipur   Diesel        MUV     188000           Manual            2
# 6058     Jaipur   Diesel        SUV     170000           Manual            1
# 6400     Jaipur   Diesel      Sedan     191867           Manual            1
# 6407     Jaipur   Diesel        SUV     157312           Manual            4
# 6421     Jaipur   Diesel      Sedan     152098           Manual            3
# 6429     Jaipur   Petrol  Hatchback     152783           Manual            4
# 6462     Jaipur   Diesel        MUV     208978           Manual            1
# 6465     Jaipur   Diesel        SUV     152633           Manual            1
# 6478     Jaipur   Petrol  Hatchback     164910           Manual            1
# 6507     Jaipur   Petrol      Sedan     176550           Manual            3
# 6532     Jaipur   Diesel  Hatchback     152702           Manual            2
# 6541     Jaipur   Petrol        SUV     182946           Manual            1
# 6562     Jaipur   Diesel      Sedan     251066           Manual            1
# 6563     Jaipur   Diesel      Sedan     208708           Manual            1
# 6570     Jaipur   Diesel  Hatchback     201161           Manual            1
# 6582     Jaipur   Diesel  Hatchback     160145           Manual            1
# 6590     Jaipur   Diesel  Hatchback     183619           Manual            1
# 6600     Jaipur   Diesel      Sedan     153007           Manual            2
# 6605     Jaipur   Petrol  Hatchback     174077           Manual            1
# 6613     Jaipur   Diesel  Hatchback     158924           Manual            1
# 6619     Jaipur   Diesel        SUV     160351           Manual            1
# 7007    Chennai   Diesel        MUV     800000           Manual            1
# 7008    Chennai   Diesel      Sedan    5500000        Automatic            1
# 7220    Chennai   Petrol  Hatchback     162049           Manual            2
# 7415    Chennai   Petrol      Sedan     200300           Manual            2
# 7732    Chennai   Diesel      Sedan     158945           Manual            1
# 7786    Chennai   Petrol      Sedan     222996           Manual            1
# 7817    Chennai   Diesel  Hatchback     176801           Manual            1
# 7907    Chennai   Diesel        MUV     175000        Automatic            1
# 7926    Chennai   Petrol      Sedan     167332           Manual            0
# 8043    Chennai   Petrol      Sedan     154931           Manual            2
# 8077    Chennai   Diesel        MUV     161471           Manual            1
# 8148    Chennai   Diesel        MUV    2000022           Manual            1
#
#                   Insurance   Manufacturer               CarModel  ModelYear  \
# 304           Comprehensive       Mahindra        Mahindra XUV500       2014
# 333           Comprehensive         Toyota        Toyota Fortuner       2014
# 336           Comprehensive         Toyota          Toyota Innova       2011
# 1230          Comprehensive         Toyota          Toyota Innova       2008
# 1234          Comprehensive         Toyota        Toyota Fortuner       2011
# 1282          Comprehensive         Toyota        Toyota Fortuner       2018
# 1285          Comprehensive          Volvo            Volvo XC 90       2010
# 1301          Comprehensive         Toyota   Toyota Innova Crysta       2016
# 1403  Third Party insurance         Toyota          Toyota Innova       2014
# 1476          Comprehensive         Toyota        Toyota Fortuner       2012
# 1600          Comprehensive         Toyota          Toyota Innova       2012
# 1693          Comprehensive         Toyota          Toyota Innova       2015
# 2103            Third Party            Kia              Kia Sonet       2021
# 3006  Third Party insurance           Audi                Audi Q3       2014
# 3020          Not Available        Hyundai            Hyundai i20       2016
# 3476  Third Party insurance        Renault          Renault Scala       2013
# 3597          Comprehensive           Ford            Ford Fiesta       2014
# 3636  Third Party insurance         Toyota          Toyota Innova       2008
# 4888          Comprehensive         Toyota        Toyota Fortuner       2013
# 5892          Comprehensive         Toyota          Toyota Innova       2012
# 6058          Comprehensive         Toyota        Toyota Fortuner       2012
# 6400          Not Available         Maruti     Maruti Swift Dzire       2016
# 6407          Not Available       Mahindra       Mahindra Scorpio       2009
# 6421          Not Available      Chevrolet        Chevrolet Cruze       2010
# 6429          Not Available         Maruti            Maruti Alto       2010
# 6462          Not Available         Maruti          Maruti Ertiga       2013
# 6465          Not Available         Nissan         Nissan Terrano       2014
# 6478          Not Available         Nissan    Nissan Micra Active       2015
# 6507          Not Available          Honda            Honda Civic       2007
# 6532          Not Available         Maruti           Maruti Swift       2014
# 6541          Not Available        Hyundai          Hyundai Creta       2017
# 6562          Not Available         Maruti     Maruti Swift Dzire       2011
# 6563          Not Available         Maruti            Maruti Ciaz       2017
# 6570          Not Available         Maruti            Maruti Ritz       2010
# 6582          Not Available         Maruti           Maruti Swift       2010
# 6590          Not Available        Hyundai            Hyundai i20       2011
# 6600          Not Available         Maruti            Maruti Ciaz       2016
# 6605          Not Available         Maruti            Maruti Alto       2006
# 6613          Not Available        Hyundai      Hyundai Grand i10       2014
# 6619          Not Available       Mahindra        Mahindra XUV500       2012
# 7007          Comprehensive         Toyota   Toyota Innova Crysta       2018
# 7008          Comprehensive  Mercedes-Benz  Mercedes-Benz C-Class       2018
# 7220          Comprehensive         Maruti            Maruti Ritz       2010
# 7415          Comprehensive          Honda             Honda City       2014
# 7732  Third Party insurance          Honda            Honda Amaze       2013
# 7786          Comprehensive          Honda            Honda Amaze       2014
# 7817          Comprehensive         Maruti           Maruti Swift       2009
# 7907          Comprehensive         Toyota   Toyota Innova Crysta       2016
# 7926                 Petrol          Honda             Honda City       2015
# 8043          Comprehensive     Volkswagen       Volkswagen Vento       2014
# 8077          Comprehensive          Honda          Honda Mobilio       2014
# 8148          Comprehensive         Toyota   Toyota Innova Crysta       2017
#
#                         VariantName  Mileage  Engine      Price  \
# 304                          W8 FWD       15    2179   850000.0
# 333                          4x2 AT       12    2982  1845000.0
# 336           2.5 V Diesel 7-seater       12    2494   950000.0
# 1230          2.5 V Diesel 7-seater       12    2494   825000.0
# 1234                     3.0 Diesel       11    2982  1195000.0
# 1282                2.8 2WD MT BSIV       14    2755  3194000.0
# 1285                      D5 AT AWD       11    2400  1090000.0
# 1301                2.4 VX MT 8 STR       13    2393  1775000.0
# 1403          2.5 Z Diesel 7 Seater       12    2494  1349000.0
# 1476                         4x4 MT       12    2982  1649000.0
# 1600              2.5 VX 7 STR BSIV       12    2494   645000.0
# 1693  2.5 G (Diesel) 7 Seater BS IV       12    2494   745000.0
# 2103             HTX Turbo iMT BSVI       18     998   975000.0
# 3006   2.0 TDI Quattro Premium Plus       15    1968  1450000.0
# 3020                  Asta 1.4 CRDi       22    1396   498000.0
# 3476                     Diesel RxZ       21    1461   260000.0
# 3597              1.5 TDCi Titanium       25    1498   300000.0
# 3636         2.5 G4 Diesel 8-seater       12    2494   499000.0
# 4888                     4x2 Manual       13    2982   970000.0
# 5892       2.5 VX (Diesel) 8 Seater       12    2494   650000.0
# 6058                         4x4 MT       12    2982  1325000.0
# 6400                            VDI       26    1248   500000.0
# 6407                             LX       12    2179   450000.0
# 6421                            LTZ       18    1991   361000.0
# 6429                             LX       19     796    68063.0
# 6462                            VDI       20    1248   450000.0
# 6465                       XL 85 PS       20    1461   216000.0
# 6478                           XV S       19    1198   215000.0
# 6507                       1.8 S MT       13    1799   150000.0
# 6532                       VDI BSIV       25    1248   450000.0
# 6541                1.6 VTVT E Plus       15    1591   700000.0
# 6562                       Vdi BSIV       19    1248   118000.0
# 6563                       1.3 Zeta       28    1248   436000.0
# 6570                            VDi       21    1248   108000.0
# 6582                      Vdi BSIII       17    1248   200000.0
# 6590                 1.4 CRDi Magna       21    1396   179000.0
# 6600                  VDi Plus SHVS       28    1248   400000.0
# 6605                       LX BSIII       19     796    54000.0
# 6613                    CRDi Sportz       24    1120   270000.0
# 6619                         W8 2WD       15    2179   415000.0
# 7007              2.4 VX MT 8S BSIV       13    2393  2150000.0
# 7008                C 220 CDI Style       19    2143  3600000.0
# 7220                            VXi       18    1197   210000.0
# 7415             1.5 V MT Exclusive       17    1497   455000.0
# 7732                      VX Diesel       24    1498   335000.0
# 7786                      VX Petrol       18    1199   300000.0
# 7817                            VDI       28    1248   250000.0
# 7907                 2.8 ZX AT BSIV       11    2755  1750000.0
# 7926                      i VTEC SV       17    1497   445000.0
# 8043                   1.6 Highline       15    1598   330000.0
# 8077                       V i-DTEC       24    1498   425000.0
# 8148                      2.4 VX MT       13    2393  1750000.0
#
#       No of Cylinder  Seats  AgeOfCar
# 304                4      7        10
# 333                4      7        10
# 336                4      7        13
# 1230               4      7        16
# 1234               4      7        13
# 1282               4      7         6
# 1285               5      7        14
# 1301               7      8         8
# 1403               4      7        10
# 1476               4      7        12
# 1600               4      7        12
# 1693               4      7         9
# 2103               3      5         3
# 3006               4      5        10
# 3020               4      5         8
# 3476               4      5        11
# 3597               4      5        10
# 3636               4      8        16
# 4888               4      7        11
# 5892               4      8        12
# 6058               4      7        12
# 6400               4      5         8
# 6407               4      9        15
# 6421               4      5        14
# 6429               3      5        14
# 6462               4      7        11
# 6465               4      5        10
# 6478               3      5         9
# 6507               4      5        17
# 6532               4      5        10
# 6541               4      5         7
# 6562               4      5        13
# 6563               4      5         7
# 6570               4      5        14
# 6582               4      5        14
# 6590               4      5        13
# 6600               4      5         8
# 6605               3      5        18
# 6613               3      5        10
# 6619               4      7        12
# 7007               7      8         6
# 7008               4      5         6
# 7220               4      5        14
# 7415               4      5        10
# 7732               4      5        11
# 7786               4      5        10
# 7817               4      5        15
# 7907               4      7         8
# 7926               4      5         9
# 8043               4      5        10
# 8077               4      7        10
# 8148               7      7         7
#
# Outliers in Price:
#            City FuelType BodyType  KmsDriven TransmissionType  NumberOwner  \
# 5     Bangalore   Diesel      SUV      20000           Manual            1
# 20    Bangalore   Diesel    Sedan     100000        Automatic            3
# 24    Bangalore   Petrol    Sedan      50000        Automatic            2
# 28    Bangalore   Petrol    Sedan      33000        Automatic            1
# 30    Bangalore   Diesel    Sedan      40000        Automatic            2
# ...         ...      ...      ...        ...              ...          ...
# 8344    Chennai   Diesel      SUV      40000        Automatic            2
# 8359    Chennai   Petrol      SUV      16500           Manual            1
# 8362    Chennai   Diesel    Sedan      60000        Automatic            2
# 8367    Chennai   Diesel      SUV      65000        Automatic            1
# 8368    Chennai   Diesel    Sedan      60000        Automatic            1
#
#                   Insurance   Manufacturer               CarModel  ModelYear  \
# 5     Third Party insurance           Jeep           Jeep Compass       2020
# 20    Third Party insurance            BMW           BMW 5 Series       2011
# 24    Third Party insurance  Mercedes-Benz  Mercedes-Benz S-Class       2016
# 28            Comprehensive  Mercedes-Benz  Mercedes-Benz E-Class       2017
# 30    Third Party insurance           Audi                Audi A4       2016
# ...                     ...            ...                    ...        ...
# 8344          Comprehensive           Audi                Audi Q3       2017
# 8359          Comprehensive     Volkswagen      Volkswagen Taigun       2021
# 8362          Comprehensive  Mercedes-Benz  Mercedes-Benz E-Class       2016
# 8367          Comprehensive     Volkswagen      Volkswagen Tiguan       2017
# 8368          Comprehensive            BMW        BMW 3 Series GT       2019
#
#                       VariantName  Mileage  Engine      Price  No of Cylinder  \
# 5              2.0 Longitude BSIV       17    1956  1900000.0               4
# 20                     520d Sedan       18    1995  2200000.0               4
# 24                        S 500 L        7    4663  4900000.0               8
# 28                Exclusive E 200       15    1991  4145000.0               4
# 30                 35 TDI Premium       17    1968  1785000.0               4
# ...                           ...      ...     ...        ...             ...
# 8344  35 TDI Quattro Premium Plus       15    1968  2400000.0               4
# 8359         1.5 TSI GT Plus BSVI       17    1498  1770000.0               4
# 8362          E250 CDI Avantgarde       13    2143  2650000.0               4
# 8367             2.0 TDI Highline       16    1968  2050000.0               4
# 8368                        Sport       21    1995  3575000.0               4
#
#       Seats  AgeOfCar
# 5         5         4
# 20        5        13
# 24        5         8
# 28        5         7
# 30        5         8
# ...     ...       ...
# 8344      5         7
# 8359      5         3
# 8362      5         8
# 8367      5         7
# 8368      5         5
#
# [839 rows x 17 columns]
#
# Outliers in AgeOfCar:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 62    Bangalore   Petrol  Hatchback     100000           Manual            2
# 228   Bangalore   Petrol      Sedan      70000           Manual            4
# 279   Bangalore   Petrol      Sedan     120000           Manual            2
# 391   Bangalore   Petrol  Hatchback      90000           Manual            2
# 449   Bangalore   Petrol  Hatchback      60000           Manual            2
# ...         ...      ...        ...        ...              ...          ...
# 7977    Chennai   Petrol      Sedan     150000           Manual            1
# 8085    Chennai   Petrol  Hatchback      91644           Manual            2
# 8086    Chennai   Petrol  Hatchback     100658           Manual            4
# 8124    Chennai   Petrol      Sedan      80030           Manual            3
# 8181    Chennai   Petrol      Sedan      85037        Automatic            3
#
#                   Insurance Manufacturer             CarModel  ModelYear  \
# 62    Third Party insurance      Hyundai         Hyundai Getz       2006
# 228   Third Party insurance         Ford            Ford Ikon       2005
# 279   Third Party insurance       Maruti        Maruti Baleno       2005
# 391   Third Party insurance      Hyundai         Hyundai Getz       2006
# 449   Third Party insurance       Maruti       Maruti Wagon R       2006
# ...                     ...          ...                  ...        ...
# 7977  Third Party insurance   Mitsubishi    Mitsubishi Lancer       2003
# 8085          Comprehensive      Hyundai  Hyundai Santro Xing       2005
# 8086          Comprehensive      Hyundai  Hyundai Santro Xing       2005
# 8124          Comprehensive    Chevrolet      Chevrolet Optra       2005
# 8181          Comprehensive        Honda     Honda New Accord       2004
#
#      VariantName  Mileage  Engine     Price  No of Cylinder  Seats  AgeOfCar
# 62           GLS       15    1341  220000.0               4      5        18
# 228    1.3 Flair       13    1299  500000.0               4      5        19
# 279          LXI       15    1590  250000.0               4      5        19
# 391          GLS       15    1341  175000.0               4      5        18
# 449          LXI       18     998  180000.0               3      5        18
# ...          ...      ...     ...       ...             ...    ...       ...
# 7977    1.5 GLXi       13    1468   90000.0               4      5        21
# 8085          XO       17    1086  100000.0               4      5        19
# 8086          XO       17    1086   70000.0               4      5        19
# 8124         1.6       17    1599  115000.0               4      5        19
# 8181       V6 AT        9    2997  250000.0               6      5        20
#
# [112 rows x 17 columns]
#
# Outliers in Mileage:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 24    Bangalore   Petrol      Sedan      50000        Automatic            2
# 70    Bangalore   Diesel  Hatchback     110000           Manual            1
# 127   Bangalore   Diesel        SUV      89000        Automatic            1
# 205   Bangalore   Diesel      Sedan      70000        Automatic            2
# 251   Bangalore   Petrol      Coupe      50000        Automatic            3
# ...         ...      ...        ...        ...              ...          ...
# 7800    Chennai   Diesel      Sedan      20000           Manual            1
# 7817    Chennai   Diesel  Hatchback     176801           Manual            1
# 7975    Chennai   Petrol        MUV       3500        Automatic            1
# 8181    Chennai   Petrol      Sedan      85037        Automatic            3
# 8335    Chennai   Diesel      Sedan      50267        Automatic            1
#
#                   Insurance   Manufacturer               CarModel  ModelYear  \
# 24    Third Party insurance  Mercedes-Benz  Mercedes-Benz S-Class       2016
# 70    Third Party insurance         Maruti           Maruti Swift       2018
# 127   Third Party insurance           Ford         Ford Endeavour       2017
# 205   Third Party insurance  Mercedes-Benz  Mercedes-Benz E-Class       2013
# 251   Third Party insurance            BMW           BMW 3 Series       2007
# ...                     ...            ...                    ...        ...
# 7800  Third Party insurance         Maruti            Maruti Ciaz       2018
# 7817          Comprehensive         Maruti           Maruti Swift       2009
# 7975          Comprehensive         Toyota   Toyota Innova Crysta       2022
# 8181          Comprehensive          Honda       Honda New Accord       2004
# 8335          Comprehensive         Maruti            Maruti Ciaz       2018
#
#                VariantName  Mileage  Engine      Price  No of Cylinder  Seats  \
# 24                 S 500 L        7    4663  4900000.0               8      5
# 70                     VDI       28    1248   690000.0               4      5
# 127    3.2 Titanium AT 4X4       10    3198  2975000.0               4      7
# 205   E 220 CDI Avantgarde       10    2148  1400000.0               4      5
# 251           330 Ci Coupe       10    2497   900000.0               6      5
# ...                    ...      ...     ...        ...             ...    ...
# 7800             1.3 Delta       28    1248   950000.0               4      5
# 7817                   VDI       28    1248   250000.0               4      5
# 7975       2.7 ZX 7 STR AT        8    2694  2655000.0               4      7
# 8181                 V6 AT        9    2997   250000.0               6      5
# 8335          Delta Diesel       28    1248   715000.0               4      5
#
#       AgeOfCar
# 24           8
# 70           6
# 127          7
# 205         11
# 251         17
# ...        ...
# 7800         6
# 7817        15
# 7975         2
# 8181        20
# 8335         6
#
# [183 rows x 17 columns]

# %%
def detect_outliers_iqr(df_d, column):
    """
    Detects outliers in the given column of the dataframe using the IQR method.
    """
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df_d[column].quantile(0.25)
    Q3 = df_d[column].quantile(0.75)

    # IQR is the difference between Q3 and Q1
    IQR = Q3 - Q1

    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df_d[(df_d[column] < lower_bound) | (df_d[column] > upper_bound)]
    
    print(f"Number of outliers in {column}: {len(outliers)}")
    
    return outliers


# Apply the function to KmsDriven, Price, and AgeOfCar
outliers_kms_driven = detect_outliers_iqr(df_filtered, 'KmsDriven')
outliers_price = detect_outliers_iqr(df_filtered, 'Price')
outliers_mileage_car = detect_outliers_iqr(df_filtered, 'Mileage')
outliers_age_of_car = detect_outliers_iqr(df_filtered, 'AgeOfCar')

# Display the outliers
print("Outliers in KmsDriven:")
print(outliers_kms_driven)

print("\nOutliers in Price:")
print(outliers_price)

print("\nOutliers in AgeOfCar:")
print(outliers_age_of_car)

print("\nOutliers in Mileage:")
print(outliers_mileage_car)
# Out:
# Number of outliers in KmsDriven: 52
# Number of outliers in Price: 839
# Number of outliers in Mileage: 183
# Number of outliers in AgeOfCar: 112
# Outliers in KmsDriven:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 304   Bangalore   Diesel        SUV     164000           Manual            2
# 333   Bangalore   Diesel        SUV     174000        Automatic            3
# 336   Bangalore   Diesel        MUV     199000           Manual            2
# 1230  Bangalore   Diesel        MUV     162000           Manual            1
# 1234  Bangalore   Diesel        SUV     180000           Manual            2
# 1282  Bangalore   Diesel        SUV     174000           Manual            1
# 1285  Bangalore   Diesel        SUV     170402        Automatic            2
# 1301  Bangalore   Diesel        MUV     157000           Manual            2
# 1403  Bangalore   Diesel        MUV     169219           Manual            2
# 1476  Bangalore   Diesel        SUV     156039           Manual            2
# 1600    Kolkata   Diesel        MUV     260000           Manual            1
# 1693    Kolkata   Diesel        MUV     177000           Manual            1
# 2103    Kolkata   Petrol        SUV     975000           Manual            1
# 3006  Hyderabad   Diesel        SUV     158000        Automatic            2
# 3020  Hyderabad   Diesel  Hatchback     188058           Manual            1
# 3476  Hyderabad   Diesel      Sedan     171000           Manual            3
# 3597  Hyderabad   Diesel      Sedan     156126           Manual            1
# 3636  Hyderabad   Diesel        MUV     236000           Manual            1
# 4888      Delhi   Diesel        SUV     230000           Manual            1
# 5892     Jaipur   Diesel        MUV     188000           Manual            2
# 6058     Jaipur   Diesel        SUV     170000           Manual            1
# 6400     Jaipur   Diesel      Sedan     191867           Manual            1
# 6407     Jaipur   Diesel        SUV     157312           Manual            4
# 6421     Jaipur   Diesel      Sedan     152098           Manual            3
# 6429     Jaipur   Petrol  Hatchback     152783           Manual            4
# 6462     Jaipur   Diesel        MUV     208978           Manual            1
# 6465     Jaipur   Diesel        SUV     152633           Manual            1
# 6478     Jaipur   Petrol  Hatchback     164910           Manual            1
# 6507     Jaipur   Petrol      Sedan     176550           Manual            3
# 6532     Jaipur   Diesel  Hatchback     152702           Manual            2
# 6541     Jaipur   Petrol        SUV     182946           Manual            1
# 6562     Jaipur   Diesel      Sedan     251066           Manual            1
# 6563     Jaipur   Diesel      Sedan     208708           Manual            1
# 6570     Jaipur   Diesel  Hatchback     201161           Manual            1
# 6582     Jaipur   Diesel  Hatchback     160145           Manual            1
# 6590     Jaipur   Diesel  Hatchback     183619           Manual            1
# 6600     Jaipur   Diesel      Sedan     153007           Manual            2
# 6605     Jaipur   Petrol  Hatchback     174077           Manual            1
# 6613     Jaipur   Diesel  Hatchback     158924           Manual            1
# 6619     Jaipur   Diesel        SUV     160351           Manual            1
# 7007    Chennai   Diesel        MUV     800000           Manual            1
# 7008    Chennai   Diesel      Sedan    5500000        Automatic            1
# 7220    Chennai   Petrol  Hatchback     162049           Manual            2
# 7415    Chennai   Petrol      Sedan     200300           Manual            2
# 7732    Chennai   Diesel      Sedan     158945           Manual            1
# 7786    Chennai   Petrol      Sedan     222996           Manual            1
# 7817    Chennai   Diesel  Hatchback     176801           Manual            1
# 7907    Chennai   Diesel        MUV     175000        Automatic            1
# 7926    Chennai   Petrol      Sedan     167332           Manual            0
# 8043    Chennai   Petrol      Sedan     154931           Manual            2
# 8077    Chennai   Diesel        MUV     161471           Manual            1
# 8148    Chennai   Diesel        MUV    2000022           Manual            1
#
#                   Insurance   Manufacturer               CarModel  ModelYear  \
# 304           Comprehensive       Mahindra        Mahindra XUV500       2014
# 333           Comprehensive         Toyota        Toyota Fortuner       2014
# 336           Comprehensive         Toyota          Toyota Innova       2011
# 1230          Comprehensive         Toyota          Toyota Innova       2008
# 1234          Comprehensive         Toyota        Toyota Fortuner       2011
# 1282          Comprehensive         Toyota        Toyota Fortuner       2018
# 1285          Comprehensive          Volvo            Volvo XC 90       2010
# 1301          Comprehensive         Toyota   Toyota Innova Crysta       2016
# 1403  Third Party insurance         Toyota          Toyota Innova       2014
# 1476          Comprehensive         Toyota        Toyota Fortuner       2012
# 1600          Comprehensive         Toyota          Toyota Innova       2012
# 1693          Comprehensive         Toyota          Toyota Innova       2015
# 2103            Third Party            Kia              Kia Sonet       2021
# 3006  Third Party insurance           Audi                Audi Q3       2014
# 3020          Not Available        Hyundai            Hyundai i20       2016
# 3476  Third Party insurance        Renault          Renault Scala       2013
# 3597          Comprehensive           Ford            Ford Fiesta       2014
# 3636  Third Party insurance         Toyota          Toyota Innova       2008
# 4888          Comprehensive         Toyota        Toyota Fortuner       2013
# 5892          Comprehensive         Toyota          Toyota Innova       2012
# 6058          Comprehensive         Toyota        Toyota Fortuner       2012
# 6400          Not Available         Maruti     Maruti Swift Dzire       2016
# 6407          Not Available       Mahindra       Mahindra Scorpio       2009
# 6421          Not Available      Chevrolet        Chevrolet Cruze       2010
# 6429          Not Available         Maruti            Maruti Alto       2010
# 6462          Not Available         Maruti          Maruti Ertiga       2013
# 6465          Not Available         Nissan         Nissan Terrano       2014
# 6478          Not Available         Nissan    Nissan Micra Active       2015
# 6507          Not Available          Honda            Honda Civic       2007
# 6532          Not Available         Maruti           Maruti Swift       2014
# 6541          Not Available        Hyundai          Hyundai Creta       2017
# 6562          Not Available         Maruti     Maruti Swift Dzire       2011
# 6563          Not Available         Maruti            Maruti Ciaz       2017
# 6570          Not Available         Maruti            Maruti Ritz       2010
# 6582          Not Available         Maruti           Maruti Swift       2010
# 6590          Not Available        Hyundai            Hyundai i20       2011
# 6600          Not Available         Maruti            Maruti Ciaz       2016
# 6605          Not Available         Maruti            Maruti Alto       2006
# 6613          Not Available        Hyundai      Hyundai Grand i10       2014
# 6619          Not Available       Mahindra        Mahindra XUV500       2012
# 7007          Comprehensive         Toyota   Toyota Innova Crysta       2018
# 7008          Comprehensive  Mercedes-Benz  Mercedes-Benz C-Class       2018
# 7220          Comprehensive         Maruti            Maruti Ritz       2010
# 7415          Comprehensive          Honda             Honda City       2014
# 7732  Third Party insurance          Honda            Honda Amaze       2013
# 7786          Comprehensive          Honda            Honda Amaze       2014
# 7817          Comprehensive         Maruti           Maruti Swift       2009
# 7907          Comprehensive         Toyota   Toyota Innova Crysta       2016
# 7926                 Petrol          Honda             Honda City       2015
# 8043          Comprehensive     Volkswagen       Volkswagen Vento       2014
# 8077          Comprehensive          Honda          Honda Mobilio       2014
# 8148          Comprehensive         Toyota   Toyota Innova Crysta       2017
#
#                         VariantName  Mileage  Engine      Price  \
# 304                          W8 FWD       15    2179   850000.0
# 333                          4x2 AT       12    2982  1845000.0
# 336           2.5 V Diesel 7-seater       12    2494   950000.0
# 1230          2.5 V Diesel 7-seater       12    2494   825000.0
# 1234                     3.0 Diesel       11    2982  1195000.0
# 1282                2.8 2WD MT BSIV       14    2755  3194000.0
# 1285                      D5 AT AWD       11    2400  1090000.0
# 1301                2.4 VX MT 8 STR       13    2393  1775000.0
# 1403          2.5 Z Diesel 7 Seater       12    2494  1349000.0
# 1476                         4x4 MT       12    2982  1649000.0
# 1600              2.5 VX 7 STR BSIV       12    2494   645000.0
# 1693  2.5 G (Diesel) 7 Seater BS IV       12    2494   745000.0
# 2103             HTX Turbo iMT BSVI       18     998   975000.0
# 3006   2.0 TDI Quattro Premium Plus       15    1968  1450000.0
# 3020                  Asta 1.4 CRDi       22    1396   498000.0
# 3476                     Diesel RxZ       21    1461   260000.0
# 3597              1.5 TDCi Titanium       25    1498   300000.0
# 3636         2.5 G4 Diesel 8-seater       12    2494   499000.0
# 4888                     4x2 Manual       13    2982   970000.0
# 5892       2.5 VX (Diesel) 8 Seater       12    2494   650000.0
# 6058                         4x4 MT       12    2982  1325000.0
# 6400                            VDI       26    1248   500000.0
# 6407                             LX       12    2179   450000.0
# 6421                            LTZ       18    1991   361000.0
# 6429                             LX       19     796    68063.0
# 6462                            VDI       20    1248   450000.0
# 6465                       XL 85 PS       20    1461   216000.0
# 6478                           XV S       19    1198   215000.0
# 6507                       1.8 S MT       13    1799   150000.0
# 6532                       VDI BSIV       25    1248   450000.0
# 6541                1.6 VTVT E Plus       15    1591   700000.0
# 6562                       Vdi BSIV       19    1248   118000.0
# 6563                       1.3 Zeta       28    1248   436000.0
# 6570                            VDi       21    1248   108000.0
# 6582                      Vdi BSIII       17    1248   200000.0
# 6590                 1.4 CRDi Magna       21    1396   179000.0
# 6600                  VDi Plus SHVS       28    1248   400000.0
# 6605                       LX BSIII       19     796    54000.0
# 6613                    CRDi Sportz       24    1120   270000.0
# 6619                         W8 2WD       15    2179   415000.0
# 7007              2.4 VX MT 8S BSIV       13    2393  2150000.0
# 7008                C 220 CDI Style       19    2143  3600000.0
# 7220                            VXi       18    1197   210000.0
# 7415             1.5 V MT Exclusive       17    1497   455000.0
# 7732                      VX Diesel       24    1498   335000.0
# 7786                      VX Petrol       18    1199   300000.0
# 7817                            VDI       28    1248   250000.0
# 7907                 2.8 ZX AT BSIV       11    2755  1750000.0
# 7926                      i VTEC SV       17    1497   445000.0
# 8043                   1.6 Highline       15    1598   330000.0
# 8077                       V i-DTEC       24    1498   425000.0
# 8148                      2.4 VX MT       13    2393  1750000.0
#
#       No of Cylinder  Seats  AgeOfCar
# 304                4      7        10
# 333                4      7        10
# 336                4      7        13
# 1230               4      7        16
# 1234               4      7        13
# 1282               4      7         6
# 1285               5      7        14
# 1301               7      8         8
# 1403               4      7        10
# 1476               4      7        12
# 1600               4      7        12
# 1693               4      7         9
# 2103               3      5         3
# 3006               4      5        10
# 3020               4      5         8
# 3476               4      5        11
# 3597               4      5        10
# 3636               4      8        16
# 4888               4      7        11
# 5892               4      8        12
# 6058               4      7        12
# 6400               4      5         8
# 6407               4      9        15
# 6421               4      5        14
# 6429               3      5        14
# 6462               4      7        11
# 6465               4      5        10
# 6478               3      5         9
# 6507               4      5        17
# 6532               4      5        10
# 6541               4      5         7
# 6562               4      5        13
# 6563               4      5         7
# 6570               4      5        14
# 6582               4      5        14
# 6590               4      5        13
# 6600               4      5         8
# 6605               3      5        18
# 6613               3      5        10
# 6619               4      7        12
# 7007               7      8         6
# 7008               4      5         6
# 7220               4      5        14
# 7415               4      5        10
# 7732               4      5        11
# 7786               4      5        10
# 7817               4      5        15
# 7907               4      7         8
# 7926               4      5         9
# 8043               4      5        10
# 8077               4      7        10
# 8148               7      7         7
#
# Outliers in Price:
#            City FuelType BodyType  KmsDriven TransmissionType  NumberOwner  \
# 5     Bangalore   Diesel      SUV      20000           Manual            1
# 20    Bangalore   Diesel    Sedan     100000        Automatic            3
# 24    Bangalore   Petrol    Sedan      50000        Automatic            2
# 28    Bangalore   Petrol    Sedan      33000        Automatic            1
# 30    Bangalore   Diesel    Sedan      40000        Automatic            2
# ...         ...      ...      ...        ...              ...          ...
# 8344    Chennai   Diesel      SUV      40000        Automatic            2
# 8359    Chennai   Petrol      SUV      16500           Manual            1
# 8362    Chennai   Diesel    Sedan      60000        Automatic            2
# 8367    Chennai   Diesel      SUV      65000        Automatic            1
# 8368    Chennai   Diesel    Sedan      60000        Automatic            1
#
#                   Insurance   Manufacturer               CarModel  ModelYear  \
# 5     Third Party insurance           Jeep           Jeep Compass       2020
# 20    Third Party insurance            BMW           BMW 5 Series       2011
# 24    Third Party insurance  Mercedes-Benz  Mercedes-Benz S-Class       2016
# 28            Comprehensive  Mercedes-Benz  Mercedes-Benz E-Class       2017
# 30    Third Party insurance           Audi                Audi A4       2016
# ...                     ...            ...                    ...        ...
# 8344          Comprehensive           Audi                Audi Q3       2017
# 8359          Comprehensive     Volkswagen      Volkswagen Taigun       2021
# 8362          Comprehensive  Mercedes-Benz  Mercedes-Benz E-Class       2016
# 8367          Comprehensive     Volkswagen      Volkswagen Tiguan       2017
# 8368          Comprehensive            BMW        BMW 3 Series GT       2019
#
#                       VariantName  Mileage  Engine      Price  No of Cylinder  \
# 5              2.0 Longitude BSIV       17    1956  1900000.0               4
# 20                     520d Sedan       18    1995  2200000.0               4
# 24                        S 500 L        7    4663  4900000.0               8
# 28                Exclusive E 200       15    1991  4145000.0               4
# 30                 35 TDI Premium       17    1968  1785000.0               4
# ...                           ...      ...     ...        ...             ...
# 8344  35 TDI Quattro Premium Plus       15    1968  2400000.0               4
# 8359         1.5 TSI GT Plus BSVI       17    1498  1770000.0               4
# 8362          E250 CDI Avantgarde       13    2143  2650000.0               4
# 8367             2.0 TDI Highline       16    1968  2050000.0               4
# 8368                        Sport       21    1995  3575000.0               4
#
#       Seats  AgeOfCar
# 5         5         4
# 20        5        13
# 24        5         8
# 28        5         7
# 30        5         8
# ...     ...       ...
# 8344      5         7
# 8359      5         3
# 8362      5         8
# 8367      5         7
# 8368      5         5
#
# [839 rows x 17 columns]
#
# Outliers in AgeOfCar:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 62    Bangalore   Petrol  Hatchback     100000           Manual            2
# 228   Bangalore   Petrol      Sedan      70000           Manual            4
# 279   Bangalore   Petrol      Sedan     120000           Manual            2
# 391   Bangalore   Petrol  Hatchback      90000           Manual            2
# 449   Bangalore   Petrol  Hatchback      60000           Manual            2
# ...         ...      ...        ...        ...              ...          ...
# 7977    Chennai   Petrol      Sedan     150000           Manual            1
# 8085    Chennai   Petrol  Hatchback      91644           Manual            2
# 8086    Chennai   Petrol  Hatchback     100658           Manual            4
# 8124    Chennai   Petrol      Sedan      80030           Manual            3
# 8181    Chennai   Petrol      Sedan      85037        Automatic            3
#
#                   Insurance Manufacturer             CarModel  ModelYear  \
# 62    Third Party insurance      Hyundai         Hyundai Getz       2006
# 228   Third Party insurance         Ford            Ford Ikon       2005
# 279   Third Party insurance       Maruti        Maruti Baleno       2005
# 391   Third Party insurance      Hyundai         Hyundai Getz       2006
# 449   Third Party insurance       Maruti       Maruti Wagon R       2006
# ...                     ...          ...                  ...        ...
# 7977  Third Party insurance   Mitsubishi    Mitsubishi Lancer       2003
# 8085          Comprehensive      Hyundai  Hyundai Santro Xing       2005
# 8086          Comprehensive      Hyundai  Hyundai Santro Xing       2005
# 8124          Comprehensive    Chevrolet      Chevrolet Optra       2005
# 8181          Comprehensive        Honda     Honda New Accord       2004
#
#      VariantName  Mileage  Engine     Price  No of Cylinder  Seats  AgeOfCar
# 62           GLS       15    1341  220000.0               4      5        18
# 228    1.3 Flair       13    1299  500000.0               4      5        19
# 279          LXI       15    1590  250000.0               4      5        19
# 391          GLS       15    1341  175000.0               4      5        18
# 449          LXI       18     998  180000.0               3      5        18
# ...          ...      ...     ...       ...             ...    ...       ...
# 7977    1.5 GLXi       13    1468   90000.0               4      5        21
# 8085          XO       17    1086  100000.0               4      5        19
# 8086          XO       17    1086   70000.0               4      5        19
# 8124         1.6       17    1599  115000.0               4      5        19
# 8181       V6 AT        9    2997  250000.0               6      5        20
#
# [112 rows x 17 columns]
#
# Outliers in Mileage:
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 24    Bangalore   Petrol      Sedan      50000        Automatic            2
# 70    Bangalore   Diesel  Hatchback     110000           Manual            1
# 127   Bangalore   Diesel        SUV      89000        Automatic            1
# 205   Bangalore   Diesel      Sedan      70000        Automatic            2
# 251   Bangalore   Petrol      Coupe      50000        Automatic            3
# ...         ...      ...        ...        ...              ...          ...
# 7800    Chennai   Diesel      Sedan      20000           Manual            1
# 7817    Chennai   Diesel  Hatchback     176801           Manual            1
# 7975    Chennai   Petrol        MUV       3500        Automatic            1
# 8181    Chennai   Petrol      Sedan      85037        Automatic            3
# 8335    Chennai   Diesel      Sedan      50267        Automatic            1
#
#                   Insurance   Manufacturer               CarModel  ModelYear  \
# 24    Third Party insurance  Mercedes-Benz  Mercedes-Benz S-Class       2016
# 70    Third Party insurance         Maruti           Maruti Swift       2018
# 127   Third Party insurance           Ford         Ford Endeavour       2017
# 205   Third Party insurance  Mercedes-Benz  Mercedes-Benz E-Class       2013
# 251   Third Party insurance            BMW           BMW 3 Series       2007
# ...                     ...            ...                    ...        ...
# 7800  Third Party insurance         Maruti            Maruti Ciaz       2018
# 7817          Comprehensive         Maruti           Maruti Swift       2009
# 7975          Comprehensive         Toyota   Toyota Innova Crysta       2022
# 8181          Comprehensive          Honda       Honda New Accord       2004
# 8335          Comprehensive         Maruti            Maruti Ciaz       2018
#
#                VariantName  Mileage  Engine      Price  No of Cylinder  Seats  \
# 24                 S 500 L        7    4663  4900000.0               8      5
# 70                     VDI       28    1248   690000.0               4      5
# 127    3.2 Titanium AT 4X4       10    3198  2975000.0               4      7
# 205   E 220 CDI Avantgarde       10    2148  1400000.0               4      5
# 251           330 Ci Coupe       10    2497   900000.0               6      5
# ...                    ...      ...     ...        ...             ...    ...
# 7800             1.3 Delta       28    1248   950000.0               4      5
# 7817                   VDI       28    1248   250000.0               4      5
# 7975       2.7 ZX 7 STR AT        8    2694  2655000.0               4      7
# 8181                 V6 AT        9    2997   250000.0               6      5
# 8335          Delta Diesel       28    1248   715000.0               4      5
#
#       AgeOfCar
# 24           8
# 70           6
# 127          7
# 205         11
# 251         17
# ...        ...
# 7800         6
# 7817        15
# 7975         2
# 8181        20
# 8335         6
#
# [183 rows x 17 columns]

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Box Plot of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.0)

for i in range(0, len(numeric_features)):
    plt.subplot(3, 3, i+1)
    sns.boxplot(x=df_filtered[numeric_features[i]])
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# ### Univariate Analysis of Categorical Features

# %%
plt.figure(figsize=(20, 30))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=40, fontweight='bold', alpha=0.8, y=1.0)

categories = [ 'City', 'FuelType', 'BodyType', 'TransmissionType', 'Insurance', 'Manufacturer']
for i in range(0, len(categories)):
    plt.subplot(4, 2, i+1)
    sns.countplot(x=df_filtered[categories[i]])
    plt.xlabel(categories[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# ### Bivariate Analysis

# %%
continuous_features=[feature for feature in numeric_features if len(df_filtered[feature].unique())>=10]
print('Num of continuos features:',continuous_features)
# Out:
# Num of continuos features: ['KmsDriven', 'ModelYear', 'Mileage', 'Engine', 'Price', 'AgeOfCar']

# %%
fig = plt.figure(figsize=(15, 20))

for i in range(0, len(continuous_features)):
    ax = plt.subplot(8, 2, i+1)

    sns.scatterplot(data= df_filtered ,x='Price', y=continuous_features[i], color='b')
    plt.xlim(0,2000000) # Limit to 25 lakhs Rupees to view clean
    plt.tight_layout()

# %% [markdown]
# ### Multivariate Analysis

# %%
df_filtered[numeric_features].corr()
# Out:
#                 KmsDriven  NumberOwner  ModelYear   Mileage    Engine  \
# KmsDriven        1.000000     0.111097  -0.237374 -0.011134  0.100584
# NumberOwner      0.111097     1.000000  -0.376964 -0.080600  0.061848
# ModelYear       -0.237374    -0.376964   1.000000  0.131294 -0.067319
# Mileage         -0.011134    -0.080600   0.131294  1.000000 -0.575444
# Engine           0.100584     0.061848  -0.067319 -0.575444  1.000000
# Price           -0.063156    -0.121321   0.301652 -0.334743  0.579411
# No of Cylinder   0.082362     0.039959  -0.094344 -0.180557  0.585335
# Seats            0.075242     0.017285  -0.000648 -0.311653  0.431670
# AgeOfCar         0.237374     0.376964  -1.000000 -0.131294  0.067319
#
#                    Price  No of Cylinder     Seats  AgeOfCar
# KmsDriven      -0.063156        0.082362  0.075242  0.237374
# NumberOwner    -0.121321        0.039959  0.017285  0.376964
# ModelYear       0.301652       -0.094344 -0.000648 -1.000000
# Mileage        -0.334743       -0.180557 -0.311653 -0.131294
# Engine          0.579411        0.585335  0.431670  0.067319
# Price           1.000000        0.376647  0.091737 -0.301652
# No of Cylinder  0.376647        1.000000  0.095400  0.094344
# Seats           0.091737        0.095400  1.000000  0.000648
# AgeOfCar       -0.301652        0.094344  0.000648  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data = df_filtered[numeric_features].corr(), annot= True, cmap= 'plasma', vmin= -1 , vmax= 1, linecolor='white', linewidths=2)
plt.show()

# %% [markdown]
# ### Check Multicollinearity for Categorical features

# %% [markdown]
# * A chi-squared test (also chi-square or χ2 test) is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test
#
# * A chi-square statistic is one way to show a relationship between two categorical variables.
#
# * Here we test correlation of Categorical columns with Target column i.e Price

# %%
from scipy.stats import chi2_contingency
chi2_test = []

for feature in categorical_features:
    if chi2_contingency(pd.crosstab(df_filtered['Price'], df_filtered[feature]))[1] < 0.05:
        chi2_test.append('Reject Null Hypothesis')
    else:
        chi2_test.append('Fail to Reject Null Hypothesis')
test_result = pd.DataFrame(data=[categorical_features, chi2_test]).T
test_result.columns = ['Categorical Features', 'Hypothesis Result']

print('-'*100)
print('Chi-Squarred Test (Checking Multi-collinearity for  Categorical features) results are as follows :')
print('-'*100)

test_result
# Out:
# ----------------------------------------------------------------------------------------------------
# Chi-Squarred Test (Checking Multi-collinearity for  Categorical features) results are as follows :
# ----------------------------------------------------------------------------------------------------
#   Categorical Features               Hypothesis Result
# 0                 City          Reject Null Hypothesis
# 1             FuelType  Fail to Reject Null Hypothesis
# 2             BodyType          Reject Null Hypothesis
# 3     TransmissionType          Reject Null Hypothesis
# 4            Insurance          Reject Null Hypothesis
# 5         Manufacturer          Reject Null Hypothesis
# 6             CarModel          Reject Null Hypothesis
# 7          VariantName          Reject Null Hypothesis

# %%
df_filtered.head()
# Out:
#         City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 0  Bangalore   Petrol  Hatchback     120000           Manual            3
# 1  Bangalore   Petrol        SUV      32706           Manual            2
# 2  Bangalore   Petrol  Hatchback      11949           Manual            1
# 3  Bangalore   Petrol      Sedan      17794           Manual            1
# 4  Bangalore   Diesel        SUV      60000           Manual            1
#
#                Insurance Manufacturer            CarModel  ModelYear  \
# 0  Third Party insurance       Maruti      Maruti Celerio       2015
# 1          Comprehensive         Ford       Ford Ecosport       2018
# 2          Comprehensive         Tata          Tata Tiago       2018
# 3          Comprehensive      Hyundai       Hyundai Xcent       2014
# 4  Third Party insurance       Maruti  Maruti SX4 S Cross       2015
#
#                 VariantName  Mileage  Engine     Price  No of Cylinder  Seats  \
# 0                       VXI       23     998  400000.0               3      5
# 1  1.5 Petrol Titanium BSIV       17    1497  811000.0               3      5
# 2           1.2 Revotron XZ       23    1199  585000.0               3      5
# 3        1.2 Kappa S Option       19    1197  462000.0               4      5
# 4             DDiS 200 Zeta       23    1248  790000.0               4      5
#
#    AgeOfCar
# 0         9
# 1         6
# 2         6
# 3        10
# 4         9

# %% [markdown]
# # Cleaning Insurance Column

# %%
# Dictionary to map incorrect values to the desired ones
insurance_mapping = {
    'Third Party insurance': 'Third Party',
    'Petrol': 'No Insurance',
    'Diesel': 'No Insurance',
    '2': 'Second Party',
    '1': 'First Party',
    'Not Available': 'No Insurance',
    'Zero Dep': 'First Party',
}

# Replace the values in the 'Insurance' column
df_filtered['Insurance'] = df_filtered['Insurance'].replace(insurance_mapping)

# Now check the unique values again to verify the changes
print(df_filtered['Insurance'].unique())
# Out:
# ['Third Party' 'Comprehensive' 'First Party' 'No Insurance' 'Second Party']

# %%
if df_filtered is not None and all(col in df_filtered.columns for col in ['Mileage_log', 'KmsDriven_log', 'Price_log', 'AgeOfCar_log']):
    df_filtered.drop(labels=['Mileage_log', 'KmsDriven_log', 'Price_log', 'AgeOfCar_log'], axis=1, inplace=True)
else:
    print("One or more columns do not exist, or df_filtered is None")

# Display the resulting DataFrame to ensure it's valid
print(df_filtered)
# Out:
# One or more columns do not exist, or df_filtered is None
#            City FuelType   BodyType  KmsDriven TransmissionType  NumberOwner  \
# 0     Bangalore   Petrol  Hatchback     120000           Manual            3
# 1     Bangalore   Petrol        SUV      32706           Manual            2
# 2     Bangalore   Petrol  Hatchback      11949           Manual            1
# 3     Bangalore   Petrol      Sedan      17794           Manual            1
# 4     Bangalore   Diesel        SUV      60000           Manual            1
# ...         ...      ...        ...        ...              ...          ...
# 8364    Chennai   Petrol  Hatchback      42891        Automatic            1
# 8365    Chennai   Diesel        SUV      59100           Manual            1
# 8366    Chennai   Petrol        SUV      55913        Automatic            1
# 8367    Chennai   Diesel        SUV      65000        Automatic            1
# 8368    Chennai   Diesel      Sedan      60000        Automatic            1
#
#           Insurance Manufacturer            CarModel  ModelYear  \
# 0       Third Party       Maruti      Maruti Celerio       2015
# 1     Comprehensive         Ford       Ford Ecosport       2018
# 2     Comprehensive         Tata          Tata Tiago       2018
# 3     Comprehensive      Hyundai       Hyundai Xcent       2014
# 4       Third Party       Maruti  Maruti SX4 S Cross       2015
# ...             ...          ...                 ...        ...
# 8364    Third Party       Maruti        Maruti Swift       2018
# 8365    Third Party      Renault      Renault Duster       2018
# 8366   No Insurance         Tata          Tata Nexon       2018
# 8367  Comprehensive   Volkswagen   Volkswagen Tiguan       2017
# 8368  Comprehensive          BMW     BMW 3 Series GT       2019
#
#                    VariantName  Mileage  Engine      Price  No of Cylinder  \
# 0                          VXI       23     998   400000.0               3
# 1     1.5 Petrol Titanium BSIV       17    1497   811000.0               3
# 2              1.2 Revotron XZ       23    1199   585000.0               3
# 3           1.2 Kappa S Option       19    1197   462000.0               4
# 4                DDiS 200 Zeta       23    1248   790000.0               4
# ...                        ...      ...     ...        ...             ...
# 8364                   AMT VXI       22    1197   620000.0               4
# 8365           85PS Diesel RxZ       19    1461   890000.0               4
# 8366     1.2 Revotron XZA Plus       17    1198   801000.0               3
# 8367          2.0 TDI Highline       16    1968  2050000.0               4
# 8368                     Sport       21    1995  3575000.0               4
#
#       Seats  AgeOfCar
# 0         5         9
# 1         5         6
# 2         5         6
# 3         5        10
# 4         5         9
# ...     ...       ...
# 8364      5         6
# 8365      5         6
# 8366      5         6
# 8367      5         7
# 8368      5         5
#
# [7966 rows x 17 columns]

# %% [markdown]
# # Save Filtered Dataset into New File

# %%
df_filtered.to_csv('data\\df_filtered.csv', index=False)
